# %% [markdown]
# # Notebook de entrenamiento de los algoritmos

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import json
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import model_from_json
from datetime import timedelta

import statsmodels.formula.api as smf

from src.dynamic_pricing_data_loader import cargar_y_preparar_datos

from Tools.ExtractData import GetDataFromETL
from Tools.Tools4TrainRN import RedNeuronal
from Tools.Tools4ProofRN import ProofRedNeuronal
from Tools.Tools4Elasticity import Elasticity
from Tools.Tools4Clasify import K_means
from Tools.Tools4ClasSuper import ClusteringSupervisado
from Tools.Tools4ProofCluster import PredictorClusters

# %% [markdown]
# # Clase para extracción de los datos

# %%
Data= GetDataFromETL(True)
# Out:
# El archivo JSON ha sido actualizado con las nuevas rutas.
# Memoria usada antes: 5183.05 MB
# Memoria usada después: 998.28 MB
# Reducción: 80.7%

# %% [markdown]
# ## Data para entrenar la red neuronal

# %%
Df_TRN= Data.D4_Train_NN() # Extraccion de datos para entrenar la Red Neuronal

# %% [markdown]
# ## Ejecución del algoritmo de red neuronal

# %%
RN= RedNeuronal(Df_TRN) # Clase para entrenar la red
# Out:
# El Error Absoluto Medio (MAE) final es de: 5.77 [Moneda]
#
# La Raíz del Error Cuadrático Medio (RMSE) final es de: 8.80 [Moneda]

# %% [markdown]
# ## Data para entrenar el clustering no supervisado

# %%
# clustering no supervisado
Df_Cluster= Data.D4_ClusterNS() # Extraccion de los datos para el clustering no supervisado

# %% [markdown]
# ## Ejecución del algoritmo de aprendizaje no supervisado

# %%
# Uso de la clase para el clustering no supervisado
kmeans = K_means()
DF_K_means = kmeans.fit(Df_Cluster,optimal_k=5,aplicar_fik=False)
# Out:
# INICIANDO CLUSTERING CON CLASE K_MEANS
# ============================================================
# ============================================================
# INICIANDO PROCESO COMPLETO DE CLUSTERING
# ============================================================
#
# 📊 PASO 1: Obteniendo datos procesados...
# ============================================================
# Calculando métricas para 488657 clientes
# ============================================================
# ✓ SBol_Vend: Total de boletos vendidos
# ✓ Prom_Pagado: Ticket promedio de compra
# ✓ Sum_Pagado: Monto total gastado
# ✓ %_Promo: Promedio de % de promoción usado
# ✓ Prom_Horas_Ant: Anticipación promedio de compra (horas)
# ✓ total_viajes_cliente: Total de viajes por cliente
# ✓ periodo_dias_cliente: Días de actividad del cliente
# ✓ dias_entre_viajes: Promedio de días entre viajes
# ✓ Venta_Ant: Proporción de ventas anticipadas
# ✓ Recencia: Días desde última compra
# ✓ Dummies Tipo creadas (2 categorías)
# ✓ Dummies Tipo creadas (8 categorías)
# ✓ Dummies Tipo creadas (3 categorías)
#
# ============================================================
# ✅ PROCESO COMPLETADO
#    Métricas creadas: 21
#    Clientes procesados: 488657
# ============================================================
# ✅ Datos procesados: 197370 filas, 21 columnas
#
# 📊 PASO 2: Transformando datos...
# ============================================================
# Calculando métricas para 488657 clientes
# ============================================================
# ✓ SBol_Vend: Total de boletos vendidos
# ✓ Prom_Pagado: Ticket promedio de compra
# ✓ Sum_Pagado: Monto total gastado
# ✓ %_Promo: Promedio de % de promoción usado
# ✓ Prom_Horas_Ant: Anticipación promedio de compra (horas)
# ✓ total_viajes_cliente: Total de viajes por cliente
# ✓ periodo_dias_cliente: Días de actividad del cliente
# ✓ dias_entre_viajes: Promedio de días entre viajes
# ✓ Venta_Ant: Proporción de ventas anticipadas
# ✓ Recencia: Días desde última compra
# ✓ Dummies Tipo creadas (2 categorías)
# ✓ Dummies Tipo creadas (8 categorías)
# ✓ Dummies Tipo creadas (3 categorías)
#
# ============================================================
# ✅ PROCESO COMPLETADO
#    Métricas creadas: 21
#    Clientes procesados: 488657
# ============================================================
# ✅ Datos procesados: 197370 filas, 21 columnas
# 🔄 Aplicando transformaciones para reducir asimetría...
# 📈 Columnas numéricas a evaluar: 20
#
# 📋 RESUMEN DE TRANSFORMACIONES:
#    ✅ Columnas transformadas: 12
#    ⏭️  Columnas sin transformar: 8
#    📊 Umbral de skew usado: 1.5
#
# 🔧 Transformaciones aplicadas:
#    • SBol_Vend: boxcox (46.56 → 0.34)
#    • Sum_Pagado: boxcox (67.69 → -0.02)
#    • Prom_Horas_Ant: log1p (4.53 → 0.01)
#    • total_viajes_cliente: boxcox (46.56 → 0.34)
#    • dias_entre_viajes: boxcox (2.54 → 0.05)
#    • Tipo_DISCAPACIDAD: sqrt (13.45 → 13.45)
#    • Tipo_ESTUDIANTE: log1p (5.86 → 5.86)
#    • Tipo_MENOR: log1p (4.02 → 4.02)
#    • Tipo_PETFRIENDLY: sqrt (53.85 → 53.85)
#    • Tipo_PROFESOR: sqrt (12.96 → 12.96)
#    • Tipo_SENECTUD: sqrt (3.23 → 3.23)
#    • Tipo_TURISTAR: log1p (8.60 → 8.60)
#
# 🎯 PASO 3: Filtrando clientes con más de 1 boleto...
#    Clientes filtrados: 197370 → 197370 (SBol_Vend > 0)
#
# 🔢 PASO 4: Preparando variables para clustering...
#    Variables para clustering: 20 columnas numéricas
# 📏 PASO 5: Escalando variables (Min-Max)...
# 🔍 PASO 6: Usando K proporcionado: 5
# 🎯 PASO 7: Entrenando KMeans con K=5...
# 🏷️  PASO 8: Asignando clusters a clientes...
#
# 📊 RESULTADOS FINALES:
# ========================================
#
# Distribución de clusters (5 clusters):
#   Cluster 0: 42224 clientes ( 21.4%)
#   Cluster 1: 21875 clientes ( 11.1%)
#   Cluster 2: 42786 clientes ( 21.7%)
#   Cluster 3: 43858 clientes ( 22.2%)
#   Cluster 4: 46627 clientes ( 23.6%)
# ============================================================
# ✅ Pipeline completado exitosamente
#    • Clientes clusterizados: 197370
#    • Número de clusters: 5
